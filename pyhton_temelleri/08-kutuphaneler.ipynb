# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as matplot

# %%
maasListesi = np.random.normal(4000,500,1000)
np.mean(maasListesi)
# Out:
# 3988.7981897844384

# %%
matplot.hist(maasListesi, 50)
matplot.show()

# %%
salary = np.random.normal(10000,1000,50)

# %%
np.mean(salary)
# Out:
# 9852.55691041379

# %%
np.std(salary)
# Out:
# 1027.9161177293836

# %%
np.median(salary)
# Out:
# 9915.527768527374

# %%
matplot.hist(salary, 10)
matplot.show()
